# %%
import pandas as pd
import os

# %%
#IGNORE THIS PART its for retrieving the files from my folders
def filesList():
    os.path.join(os.getcwd(),'air-pollution-datasets')
    mypath = os.path.join(os.getcwd(),'air-pollution-datasets')
    onlyfiles = [os.path.join(mypath, f) for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]
    return onlyfiles

# %%
filesList()
# Out:
# ['C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\CA-2018.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\CA-2019.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\CA-2020.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\IL-2018.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\IL-2019.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\IL-2020.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\MA-2018.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\MA-2019.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\MA-2020.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\NY-2018.csv',
#  'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\NY-2019.csv',
# ...

# %%
def createAirPolData():
    list_of_files = filesList()
    air_state_df = pd.DataFrame()
    for file in list_of_files: # loop through each file in the list
        df = pd.read_csv(file) # read csv into data frame
        air_mean = df.groupby('Date')['Daily Mean PM2.5 Concentration'].mean() # group by date and take the mean of pm25
        air_df = pd.DataFrame(air_mean) # convert the results to data frame
        air_df['State'] = file[-11:-9] # add column State and pick the state name from the file name
        air_state_df = pd.concat([air_state_df, air_df]) # concatenate the data frames 
    return air_state_df

# %%
st = createAirPolData()

# %%
# EXAMPLE 
file = filesList()[0] #change this to ur file in your folder
file
# Out:
# 'C:\\Users\\Reem\\Documents\\volunteer-covid-19\\air-pollution-datasets\\CA-2018.csv'

# %%
df = pd.read_csv(file) # read csv into data frame

# %%
df.head() # check the data frame
# Out:
#          Date Source   Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  01/01/2018    AQS  60010007    3                            28.1  ug/m3 LC
# 1  01/02/2018    AQS  60010007    3                            24.5  ug/m3 LC
# 2  01/03/2018    AQS  60010007    3                            39.0  ug/m3 LC
# 3  01/04/2018    AQS  60010007    3                            20.9  ug/m3 LC
# 4  01/05/2018    AQS  60010007    3                             5.5  ug/m3 LC
#
#    DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               85  Livermore                1             100.0
# 1               77  Livermore                1             100.0
# 2              110  Livermore                1             100.0
# 3               70  Livermore                1             100.0
# 4               23  Livermore                1             100.0
#
#    AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  CBSA_CODE  \
# ...

# %%
df.shape # check the number of data in the data frame
# Out:
# (51485, 20)

# %%
air_mean = df.groupby('Date')['Daily Mean PM2.5 Concentration'].mean() # group by date and take the mean of pm25
air_mean
# Out:
# Date
# 01/01/2018    34.696667
# 01/02/2018    27.249741
# 01/03/2018    28.133871
# 01/04/2018    19.480328
# 01/05/2018    11.334731
# 01/06/2018    10.451639
# 01/07/2018    12.844715
# 01/08/2018     9.346597
# 01/09/2018     4.134959
# 01/10/2018     7.538017
# 01/11/2018    11.084242
# 01/12/2018    13.341322
# 01/13/2018    11.511667
# 01/14/2018    12.146073
# 01/15/2018    15.554237
# 01/16/2018    16.544444
# 01/17/2018    14.851923
# 01/18/2018    15.269919
# 01/19/2018     8.505738
# 01/20/2018     6.750794
# 01/21/2018    10.098333
# 01/22/2018     9.128571
# 01/23/2018     8.373494
# 01/24/2018    10.028099
# 01/25/2018     6.594167
# 01/26/2018     7.880851
# 01/27/2018     8.997500
# 01/28/2018     9.132203
# 01/29/2018    11.050602
# 01/30/2018    12.941176
#                 ...
# 12/02/2018     6.957143
# 12/03/2018     8.078862
# 12/04/2018     7.812887
# 12/05/2018     6.765854
# 12/06/2018     7.053659
# 12/07/2018     9.528743
# 12/08/2018    14.160317
# ...

# %%
air_df = pd.DataFrame(air_mean) # convert the results to data frame
air_df
# Out:
#             Daily Mean PM2.5 Concentration
# Date
# 01/01/2018                       34.696667
# 01/02/2018                       27.249741
# 01/03/2018                       28.133871
# 01/04/2018                       19.480328
# 01/05/2018                       11.334731
# 01/06/2018                       10.451639
# 01/07/2018                       12.844715
# 01/08/2018                        9.346597
# 01/09/2018                        4.134959
# 01/10/2018                        7.538017
# 01/11/2018                       11.084242
# 01/12/2018                       13.341322
# 01/13/2018                       11.511667
# 01/14/2018                       12.146073
# 01/15/2018                       15.554237
# 01/16/2018                       16.544444
# 01/17/2018                       14.851923
# 01/18/2018                       15.269919
# 01/19/2018                        8.505738
# 01/20/2018                        6.750794
# 01/21/2018                       10.098333
# ...

# %%
state_name = file[-11:-9] # getting the state name from the file name you can change these numbers to fit your file
#state_name = 'CA' # or just type it in state_name = 'CA'
state_name
# Out:
# 'CA'

# %%
air_df['State'] = state_name # add column State and pick the state name from the file name or the other method
air_df
# Out:
#             Daily Mean PM2.5 Concentration State
# Date
# 01/01/2018                       34.696667    CA
# 01/02/2018                       27.249741    CA
# 01/03/2018                       28.133871    CA
# 01/04/2018                       19.480328    CA
# 01/05/2018                       11.334731    CA
# 01/06/2018                       10.451639    CA
# 01/07/2018                       12.844715    CA
# 01/08/2018                        9.346597    CA
# 01/09/2018                        4.134959    CA
# 01/10/2018                        7.538017    CA
# 01/11/2018                       11.084242    CA
# 01/12/2018                       13.341322    CA
# 01/13/2018                       11.511667    CA
# 01/14/2018                       12.146073    CA
# 01/15/2018                       15.554237    CA
# 01/16/2018                       16.544444    CA
# 01/17/2018                       14.851923    CA
# 01/18/2018                       15.269919    CA
# ...

# %%
# last step concatenate data frames as shown in the function
